# %%
#import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import dataset

# %%
file_path =("/content/Most Streamed Spotify Songs 2024.csv")

# %%
data = pd.read_csv(file_path, encoding='latin-1')

# %%
#preprocessing data

# %%
data.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  ...  SiriusXM Spins  \
# ...

# %%
data.tail()
# Out:
#                                 Track                        Album Name  \
# 4595                For the Last Time                 For the Last Time
# 4596                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4597            Grace (feat. 42 Dugg)                           My Turn
# 4598              Nashe Si Chadh Gayi             November Top 10 Songs
# 4599  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#             Artist Release Date          ISRC All Time Rank  Track Score  \
# 4595   $uicideboy$     9/5/2017  QM8DG1703420         4,585         19.4
# 4596    Atif Aslam    7/27/2018  INT101800122         4,575         19.4
# 4597      Lil Baby    2/28/2020  USUG12000043         4,571         19.4
# 4598  Arijit Singh    11/8/2016  INY091600067         4,591         19.4
# 4599     Arcï¿½ï¿½    4/11/2017  USB271700107         4,593         19.4
#
#      Spotify Streams Spotify Playlist Count Spotify Playlist Reach  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   object
#  1   Album Name                  4600 non-null   object
#  2   Artist                      4595 non-null   object
#  3   Release Date                4600 non-null   object
#  4   ISRC                        4600 non-null   object
#  5   All Time Rank               4600 non-null   object
#  6   Track Score                 4600 non-null   float64
#  7   Spotify Streams             4487 non-null   object
#  8   Spotify Playlist Count      4530 non-null   object
#  9   Spotify Playlist Reach      4528 non-null   object
#  10  Spotify Popularity          3796 non-null   float64
#  11  YouTube Views               4292 non-null   object
#  12  YouTube Likes               4285 non-null   object
# ...

# %%
data.describe()
# Out:
#        Track Score  Spotify Popularity  Apple Music Playlist Count  \
# count  4600.000000         3796.000000                  4039.00000
# mean     41.844043           63.501581                    54.60312
# std      38.543766           16.186438                    71.61227
# min      19.400000            1.000000                     1.00000
# 25%      23.300000           61.000000                    10.00000
# 50%      29.900000           67.000000                    28.00000
# 75%      44.425000           73.000000                    70.00000
# max     725.400000           96.000000                   859.00000
#
#        Deezer Playlist Count  Amazon Playlist Count  TIDAL Popularity  \
# count            3679.000000            3545.000000               0.0
# mean               32.310954              25.348942               NaN
# std                54.274538              25.989826               NaN
# min                 1.000000               1.000000               NaN
# ...

# %%
data.isnull()
# Out:
#       Track  Album Name  Artist  Release Date   ISRC  All Time Rank  \
# 0     False       False   False         False  False          False
# 1     False       False   False         False  False          False
# 2     False       False   False         False  False          False
# 3     False       False   False         False  False          False
# 4     False       False   False         False  False          False
# ...     ...         ...     ...           ...    ...            ...
# 4595  False       False   False         False  False          False
# 4596  False       False   False         False  False          False
# 4597  False       False   False         False  False          False
# 4598  False       False   False         False  False          False
# 4599  False       False   False         False  False          False
#
#       Track Score  Spotify Streams  Spotify Playlist Count  \
# 0           False            False                   False
# ...

# %%
data.isnull().sum()
# Out:
# Track                            0
# Album Name                       0
# Artist                           5
# Release Date                     0
# ISRC                             0
# All Time Rank                    0
# Track Score                      0
# Spotify Streams                113
# Spotify Playlist Count          70
# Spotify Playlist Reach          72
# Spotify Popularity             804
# YouTube Views                  308
# YouTube Likes                  315
# TikTok Posts                  1173
# TikTok Likes                   980
# TikTok Views                   981
# YouTube Playlist Reach        1009
# Apple Music Playlist Count     561
# AirPlay Spins                  498
# SiriusXM Spins                2123
# Deezer Playlist Count          921
# Deezer Playlist Reach          928
# Amazon Playlist Count         1055
# Pandora Streams               1106
# Pandora Track Stations        1268
# Soundcloud Streams            3333
# Shazam Counts                  577
# ...

# %%
#handling missing values

# %%
data_missing = pd.DataFrame(data.isnull().sum()).reset_index().rename(columns={'index': 'Track', 0: 'Missing Values'})
data_missing.drop(index=data.index[0], axis=0, inplace=True)
data_missing[data_missing['Missing Values']>0].sort_values(by='Missing Values', ascending=False)
# Out:
#                          Track  Missing Values
# 27            TIDAL Popularity            4600
# 25          Soundcloud Streams            3333
# 19              SiriusXM Spins            2123
# 24      Pandora Track Stations            1268
# 13                TikTok Posts            1173
# 23             Pandora Streams            1106
# 22       Amazon Playlist Count            1055
# 16      YouTube Playlist Reach            1009
# 15                TikTok Views             981
# 14                TikTok Likes             980
# 21       Deezer Playlist Reach             928
# 20       Deezer Playlist Count             921
# 10          Spotify Popularity             804
# 26               Shazam Counts             577
# 17  Apple Music Playlist Count             561
# 18               AirPlay Spins             498
# 12               YouTube Likes             315
# 11               YouTube Views             308
# 7              Spotify Streams             113
# ...

# %%
data.drop('TIDAL Popularity', axis=1, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   object
#  1   Album Name                  4600 non-null   object
#  2   Artist                      4595 non-null   object
#  3   Release Date                4600 non-null   object
#  4   ISRC                        4600 non-null   object
#  5   All Time Rank               4600 non-null   object
#  6   Track Score                 4600 non-null   float64
#  7   Spotify Streams             4487 non-null   object
#  8   Spotify Playlist Count      4530 non-null   object
#  9   Spotify Playlist Reach      4528 non-null   object
#  10  Spotify Popularity          3796 non-null   float64
#  11  YouTube Views               4292 non-null   object
#  12  YouTube Likes               4285 non-null   object
# ...

# %%
data.drop('Soundcloud Streams', axis=1, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   object
#  1   Album Name                  4600 non-null   object
#  2   Artist                      4595 non-null   object
#  3   Release Date                4600 non-null   object
#  4   ISRC                        4600 non-null   object
#  5   All Time Rank               4600 non-null   object
#  6   Track Score                 4600 non-null   float64
#  7   Spotify Streams             4487 non-null   object
#  8   Spotify Playlist Count      4530 non-null   object
#  9   Spotify Playlist Reach      4528 non-null   object
#  10  Spotify Popularity          3796 non-null   float64
#  11  YouTube Views               4292 non-null   object
#  12  YouTube Likes               4285 non-null   object
# ...

# %%
data_missing = pd.DataFrame(data.isnull().sum()).reset_index().rename(columns={'index': 'Track', 0: 'Missing Values'})
data_missing.drop(index=data.index[0], axis=0, inplace=True)
data_missing[data_missing['Missing Values']>0].sort_values(by='Missing Values', ascending=False)
# Out:
#                          Track  Missing Values
# 19              SiriusXM Spins            2123
# 24      Pandora Track Stations            1268
# 13                TikTok Posts            1173
# 23             Pandora Streams            1106
# 22       Amazon Playlist Count            1055
# 16      YouTube Playlist Reach            1009
# 15                TikTok Views             981
# 14                TikTok Likes             980
# 21       Deezer Playlist Reach             928
# 20       Deezer Playlist Count             921
# 10          Spotify Popularity             804
# 25               Shazam Counts             577
# 17  Apple Music Playlist Count             561
# 18               AirPlay Spins             498
# 12               YouTube Likes             315
# 11               YouTube Views             308
# 7              Spotify Streams             113
# 9       Spotify Playlist Reach              72
# 8       Spotify Playlist Count              70
# ...

# %%
data.drop('SiriusXM Spins', axis=1, inplace=True)

# %%
data.drop('Pandora Track Stations',axis=1,inplace=True)

# %%
data.drop('TikTok Posts',axis=1,inplace=True)

# %%
data.drop('Pandora Streams',axis=1,inplace=True)

# %%
data.drop('Amazon Playlist Count',axis=1,inplace=True)

# %%
data.drop('YouTube Playlist Reach',axis=1,inplace=True)

# %%
data.drop('TikTok Views',axis=1,inplace=True)

# %%
data.drop('TikTok Likes',axis=1,inplace=True)

# %%
data.drop('Deezer Playlist Reach',axis=1,inplace=True)

# %%
data.drop('Deezer Playlist Count',axis=1,inplace=True)

# %%
data.drop('Spotify Popularity',axis=1,inplace=True)

# %%
if 'Shazam Counts' in data.columns:
   data.drop('Shazam Counts',axis=1,inplace=True)

# %%
if 'Apple Music Playlist Count'in data.columns:
   data.drop('Apple Music Playlist Count',axis=1,inplace=True)

# %%
if 'AirPlay Spins'in data.columns:
    data.drop('AirPlay Spins',axis=1,inplace=True)

# %%
if 'YouTube Likes'in data.columns:
    data.drop('YouTube Likes',axis=1,inplace=True)

# %%
if 'YouTube views'in data.columns:
    data.drop('YouTube Views',axis=1,inplace=True)

# %%
if 'Spotify Streams'in data.columns:
    data.drop('Spotify Streams',axis=1,inplace=True)

# %%
if 'Spotify Playlist Reach'in data.columns:
      data.drop('Spotify Playlist Reach',axis=1,inplace=True)

# %%
if 'Spotify Playlist Count'in data.columns:
    data.drop('Spotify Playlist Count',axis=1,inplace=True)

# %%
if 'Artis'in data.columns:
    data.drop('Artis',axis=1,inplace=True)

# %%
#converting datatypes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Track           4600 non-null   object
#  1   Album Name      4600 non-null   object
#  2   Artist          4595 non-null   object
#  3   Release Date    4600 non-null   object
#  4   ISRC            4600 non-null   object
#  5   All Time Rank   4600 non-null   object
#  6   Track Score     4600 non-null   float64
#  7   YouTube Views   4292 non-null   object
#  8   Explicit Track  4600 non-null   int64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 323.6+ KB

# %%
#take track and convert object to int data type

# %%
data['Release Date'] = data['Release Date'].apply(lambda x: str(x).replace(',', ''))
data['Release Date']
# Out:
# 0       4/26/2024
# 1        5/4/2024
# 2       3/19/2024
# 3       1/12/2023
# 4       5/31/2024
#           ...
# 4595     9/5/2017
# 4596    7/27/2018
# 4597    2/28/2020
# 4598    11/8/2016
# 4599    4/11/2017
# Name: Release Date, Length: 4600, dtype: object

# %%
# show EDA of our data

# %%
data_eda = data.copy()

# %%
data.hist(figsize=(20,10),bins=7,color='blue')
# Out:
# array([[<Axes: title={'center': 'Track Score'}>,
#         <Axes: title={'center': 'Explicit Track'}>]], dtype=object)

# %%
#outlier detection

# %%
plt.figure(figsize=(20,10))
sns.boxplot(y = data["Explicit Track"])
# Out:
# <Axes: ylabel='Explicit Track'>
